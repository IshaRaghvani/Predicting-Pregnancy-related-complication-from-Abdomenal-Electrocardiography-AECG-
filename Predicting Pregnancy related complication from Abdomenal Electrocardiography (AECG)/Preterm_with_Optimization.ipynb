# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(32)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "classification"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from pandas.plotting import scatter_matrix # optional
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# %%
# read in the data
fetal = pd.read_csv("https://raw.githubusercontent.com/SamyDahman/MLData/main/fetal_health.csv")
fetal.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             73.0                                   0.5
# 1                             17.0                                   2.1
# 2                             16.0                                   2.1
# 3                             16.0                                   2.4
# 4                             16.0                                   2.4
#
#    percentage_of_time_with_abnormal_long_term_variability  ...  histogram_min  \
# 0                                               43.0       ...           62.0
# 1                                                0.0       ...           68.0
# 2                                                0.0       ...           68.0
# 3                                                0.0       ...           53.0
# 4                                                0.0       ...           53.0
#
#    histogram_max  histogram_number_of_peaks  histogram_number_of_zeroes  \
# 0          126.0                        2.0                         0.0
# 1          198.0                        6.0                         1.0
# 2          198.0                        5.0                         1.0
# 3          170.0                       11.0                         0.0
# 4          170.0                        9.0                         0.0
#
#    histogram_mode  histogram_mean  histogram_median  histogram_variance  \
# 0           120.0           137.0             121.0                73.0
# 1           141.0           136.0             140.0                12.0
# 2           141.0           135.0             138.0                13.0
# 3           137.0           134.0             137.0                13.0
# 4           137.0           136.0             138.0                11.0
#
#    histogram_tendency  fetal_health
# 0                 1.0           2.0
# 1                 0.0           1.0
# 2                 0.0           1.0
# 3                 1.0           1.0
# 4                 1.0           1.0
#
# [5 rows x 22 columns]

# %%
# view the info of the dataset
fetal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
#  8   mean_value_of_short_term_variability                    2126 non-null   float64
#  9   percentage_of_time_with_abnormal_long_term_variability  2126 non-null   float64
#  10  mean_value_of_long_term_variability                     2126 non-null   float64
#  11  histogram_width                                         2126 non-null   float64
#  12  histogram_min                                           2126 non-null   float64
#  13  histogram_max                                           2126 non-null   float64
#  14  histogram_number_of_peaks                               2126 non-null   float64
#  15  histogram_number_of_zeroes                              2126 non-null   float64
#  16  histogram_mode                                          2126 non-null   float64
#  17  histogram_mean                                          2126 non-null   float64
#  18  histogram_median                                        2126 non-null   float64
#  19  histogram_variance                                      2126 non-null   float64
#  20  histogram_tendency                                      2126 non-null   float64
#  21  fetal_health                                            2126 non-null   float64
# dtypes: float64(22)
# memory usage: 365.5 KB

# %%
# see the statistics of each feature
fetal.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# std               0.002960              0.000057                  0.000590
# min               0.000000              0.000000                  0.000000
# 25%               0.000000              0.000000                  0.000000
# 50%               0.000000              0.000000                  0.000000
# 75%               0.003000              0.000000                  0.000000
# max               0.015000              0.001000                  0.005000
#
#        abnormal_short_term_variability  mean_value_of_short_term_variability  \
# count                      2126.000000                           2126.000000
# mean                         46.990122                              1.332785
# std                          17.192814                              0.883241
# min                          12.000000                              0.200000
# 25%                          32.000000                              0.700000
# 50%                          49.000000                              1.200000
# 75%                          61.000000                              1.700000
# max                          87.000000                              7.000000
#
#        percentage_of_time_with_abnormal_long_term_variability  ...  \
# count                                         2126.00000       ...
# mean                                             9.84666       ...
# std                                             18.39688       ...
# min                                              0.00000       ...
# 25%                                              0.00000       ...
# 50%                                              0.00000       ...
# 75%                                             11.00000       ...
# max                                             91.00000       ...
#
#        histogram_min  histogram_max  histogram_number_of_peaks  \
# count    2126.000000    2126.000000                2126.000000
# mean       93.579492     164.025400                   4.068203
# std        29.560212      17.944183                   2.949386
# min        50.000000     122.000000                   0.000000
# 25%        67.000000     152.000000                   2.000000
# 50%        93.000000     162.000000                   3.000000
# 75%       120.000000     174.000000                   6.000000
# max       159.000000     238.000000                  18.000000
#
#        histogram_number_of_zeroes  histogram_mode  histogram_mean  \
# count                 2126.000000     2126.000000     2126.000000
# mean                     0.323612      137.452023      134.610536
# std                      0.706059       16.381289       15.593596
# min                      0.000000       60.000000       73.000000
# 25%                      0.000000      129.000000      125.000000
# 50%                      0.000000      139.000000      136.000000
# 75%                      0.000000      148.000000      145.000000
# max                     10.000000      187.000000      182.000000
#
#        histogram_median  histogram_variance  histogram_tendency  fetal_health
# count       2126.000000         2126.000000         2126.000000   2126.000000
# mean         138.090310           18.808090            0.320320      1.304327
# std           14.466589           28.977636            0.610829      0.614377
# min           77.000000            0.000000           -1.000000      1.000000
# 25%          129.000000            2.000000            0.000000      1.000000
# 50%          139.000000            7.000000            0.000000      1.000000
# 75%          148.000000           24.000000            1.000000      1.000000
# max          186.000000          269.000000            1.000000      3.000000
#
# [8 rows x 22 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fetal.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#ratio of healthy fetuses (represented by fetal_health = 1) in the dataset.
asdf = fetal.copy()
helthybois = asdf["fetal_health"]
acc = len(helthybois[helthybois==1])/len(helthybois)
print(acc)
# Out:
# 0.7784571966133584

# %%
# split into training and testing dataset
train_set, test_set = train_test_split(fetal, test_size=0.2, random_state=42)
print(train_set.shape )
print(test_set.shape )
# Out:
# (1700, 22)
# (426, 22)

# %%
train_label = train_set['fetal_health'].copy()
train_set = train_set.drop(["fetal_health"], axis=1)
test_label = test_set['fetal_health'].copy()
test_set = test_set.drop(["fetal_health"], axis=1)

# %%
# pipeline for transforming the numeric variables
num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="median")),
        ('std_scaler', StandardScaler()),
    ])

# %%
# pipeline for transforming the entire dataset
# in this case, we only have numeric variables in our dataset.

num_attribs = list(train_set)

full_pipeline = ColumnTransformer([
        ("num", num_pipeline, num_attribs),
    ])

# %%
# transform the train_set and test_set
train_prepared = full_pipeline.fit_transform(train_set)
test_prepared = full_pipeline.transform(test_set)
print(train_prepared.shape)
print(test_prepared.shape)
# Out:
# (1700, 21)
# (426, 21)

# %% [markdown]
# Classification
# We'll start by trying the ensemble learning model for classification:
#
# This model will use several different classifiers and allow them to vote in order to classify an entry. Our classifiers will be Random Forest Classifier, Support Vector Machine, and Logistic Regression.

# %%
# We make the appropriate imports
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# We are creating the model for each classifier
log_clf = LogisticRegression(solver="lbfgs", random_state=32)
rnd_clf = RandomForestClassifier(n_estimators=100, random_state=32)
svm_clf = SVC(gamma="scale", probability=True, random_state=32)

# We are creating the ensemble classifier that uses all the above classifiers
voting_clf = VotingClassifier(
    estimators=[('lr', log_clf), ('rf', rnd_clf), ('svc', svm_clf)],
    voting='soft')

# %%
from sklearn.metrics import confusion_matrix, f1_score
import numpy as np

def clf_scores(y_actual, y_predict):
  conf = confusion_matrix(y_actual, y_predict) # get confusion matrix
  print("Confusion Matrix:\n", conf)
  recall = np.diagonal(conf) / (np.sum(conf,axis=1)) # recall of each class
  precision = np.diagonal(conf) / (np.sum(conf,axis=0)) # precision of each class
  f1 = 2*recall*precision / (precision + recall)
  print("Precision:\n", precision, "\nRecall:\n", recall, "\nF1 Score:\n", f1, "\n")
  return conf, recall, precision, f1

# %%
from sklearn.metrics import accuracy_score

# Train each model
print("Scoring Metrics for each Model:\n")
for clf in (log_clf, rnd_clf, svm_clf, voting_clf):
    clf.fit(train_prepared, train_label)
    y_pred = clf.predict(test_prepared)
    print(clf.__class__.__name__, accuracy_score(test_label, y_pred))
    clf_scores(test_label, y_pred)
# Out:
# Scoring Metrics for each Model:
#
# LogisticRegression 0.8802816901408451
# Confusion Matrix:
#  [[311  19   3]
#  [ 18  42   4]
#  [  2   5  22]]
# Precision:
#  [0.93957704 0.63636364 0.75862069]
# Recall:
#  [0.93393393 0.65625    0.75862069]
# F1 Score:
#  [0.93674699 0.64615385 0.75862069]
#
# RandomForestClassifier 0.9507042253521126
# Confusion Matrix:
#  [[327   5   1]
#  [ 10  52   2]
#  [  1   2  26]]
# Precision:
#  [0.96745562 0.88135593 0.89655172]
# Recall:
#  [0.98198198 0.8125     0.89655172]
# F1 Score:
#  [0.97466468 0.84552846 0.89655172]
#
# SVC 0.903755868544601
# Confusion Matrix:
#  [[317  15   1]
#  [ 17  46   1]
#  [  2   5  22]]
# Precision:
#  [0.94345238 0.6969697  0.91666667]
# Recall:
#  [0.95195195 0.71875    0.75862069]
# F1 Score:
#  [0.94768311 0.70769231 0.83018868]
#
# VotingClassifier 0.9248826291079812
# Confusion Matrix:
#  [[322  11   0]
#  [ 14  48   2]
#  [  1   4  24]]
# Precision:
#  [0.95548961 0.76190476 0.92307692]
# Recall:
#  [0.96696697 0.75       0.82758621]
# F1 Score:
#  [0.96119403 0.75590551 0.87272727]

# %% [markdown]
# We observe that the individual Random Forest Classifier is better than every other model as well as the Voting Classifier

# %%
#AdaBoosting

from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
# We create the AdaBoost Classifier using Decision Tree
ada_clf = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1), n_estimators=200,
    algorithm="SAMME.R", learning_rate=0.5, random_state=32)

# Train on the data
ada_clf.fit(train_prepared, train_label)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1),
#                    learning_rate=0.5, n_estimators=200, random_state=32)

# %%
# Looking at accuracy of model
y_pred = ada_clf.predict(test_prepared)
print("Accuracy of Decision Tree Boosting: " + str(accuracy_score(test_label, y_pred)))
clf_scores(test_label, y_pred);
# Out:
# Accuracy of Decision Tree Boosting: 0.9061032863849765
# Confusion Matrix:
#  [[319  13   1]
#  [ 17  46   1]
#  [  8   0  21]]
# Precision:
#  [0.92732558 0.77966102 0.91304348]
# Recall:
#  [0.95795796 0.71875    0.72413793]
# F1 Score:
#  [0.94239291 0.74796748 0.80769231]

# %% [markdown]
# It seems that singular Random-Forest Classifier outperforms all the other models. We will proceed with it and further optimize.
#
# ## Optimization
# New Scoring Function for Optimization.
# We begin by creating our own loss function for grid search to look for. Finding the best model is dependent on how "best" is defined. As our project concerns medical health, we insist that the recall must be high so that if fetal health is poor, it will not go undetected. We do not want any false negatives on the poor health classifiers. At the same time, however, we cannot let precision drop too low, so we define our new scoring function to be similar to the F1 score, but with more weight given to recall. The F1 formula is f1 = 2 / ( 1/p + 1/r ) for precision p and recall r. We define our unique scoring function:
# f2 = ( 1 + a ) / ( 1/p + a*1/r )
# which is the same as the f1 metric but with weight "a" applied to the recall term, so that recall will be made more important than precision for a > 1. Additionally, the precision and recall used in these formulas can be a weighted average of the recalls for each class, with more weight given to the unhealthy class.The f2 score will always be between 0 and 1 if the weight vector is normalized such that the components sum to 1.

# %%
from sklearn.metrics import make_scorer

def f2(y, y_pred, **kwargs):
  a = 2 # adjust this for recall weight
  weights = np.array([1,1,2]) # adjust this for recall weight on each class
  weights = weights / np.sum(weights) # normalize weights; weights for direction, a for magnitude

  conf = confusion_matrix(y, y_pred) # get confusion matrix
  recall = np.diagonal(conf) / (np.sum(conf,axis=1)) # recall scores for each class
  precision = np.diagonal(conf) / (np.sum(conf,axis=0)) # precision scores for each class

  r = np.dot(weights, recall)  # weighted recall average
  p = np.mean(precision) # precision average
  f2 = ( 1 + a ) / ( 1/p + a*1/r ) # f2 formula
  return f2

f2_score = make_scorer(f2, greater_is_better=True)

# %%
# !pip install lime shap
# Out:
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.46.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from lime) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lime) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lime) (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lime) (4.66.5)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from lime) (1.5.2)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.10/dist-packages (from lime) (0.24.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (24.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (3.1.0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->lime) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->lime) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=b6644ffb8e2ec4c7e56c2474941e20159c6b1621d423a8f6c7a382075393e2a7
#   Stored in directory: /root/.cache/pip/wheels/fd/a2/af/9ac0a1a85a27f314a06b39e1f492bee1547d52549a4606ed89
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1

# %%
import lime
import lime.lime_tabular

# Initialize LIME explainer
explainer = lime.lime_tabular.LimeTabularExplainer(
    train_prepared,
    feature_names=num_attribs,
    class_names=['Healthy', 'Suspect', 'Pathological'],
    verbose=True,
    mode='classification'
)

# Select an instance to explain (let's take the first test sample)
i = 0  # index of the sample to explain
instance = test_prepared[i].reshape(1, -1)

# Predict and explain the instance
exp = explainer.explain_instance(instance[0], forest_clf.predict_proba, num_features=10)

# Show the explanation
exp.show_in_notebook(show_table=True)

# %% [markdown]
# **Random and Grid Searching Hyperparameters.**

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

forest_clf = RandomForestClassifier(random_state=32)

param_dist = {'n_estimators': randint(1,1000),
              'min_samples_split': randint(2,10),
              'max_depth': randint(1,250),
              'min_samples_leaf': randint(1,10),
              'max_features': randint(1,22),
              'max_leaf_nodes': randint(2,500)
              }
n_iter_search = 100

random_search = RandomizedSearchCV(forest_clf, param_distributions=param_dist,
                                   n_iter=n_iter_search, scoring=f2_score)

random_search.fit(train_prepared, train_label)

cvres = random_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
  print(mean_score, params)

print("Best: ", random_search.best_params_)
# Out:
# 0.8708297227439145 {'max_depth': 216, 'max_features': 12, 'max_leaf_nodes': 391, 'min_samples_leaf': 7, 'min_samples_split': 6, 'n_estimators': 959}
# 0.8639176735186942 {'max_depth': 89, 'max_features': 20, 'max_leaf_nodes': 254, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 602}
# 0.801182261903217 {'max_depth': 4, 'max_features': 6, 'max_leaf_nodes': 236, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 466}
# 0.7051701614213622 {'max_depth': 4, 'max_features': 2, 'max_leaf_nodes': 420, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 555}
# 0.8819479454947377 {'max_depth': 83, 'max_features': 11, 'max_leaf_nodes': 470, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 101}
# 0.8430288862505024 {'max_depth': 186, 'max_features': 6, 'max_leaf_nodes': 251, 'min_samples_leaf': 7, 'min_samples_split': 7, 'n_estimators': 780}
# 0.8744645311655856 {'max_depth': 63, 'max_features': 12, 'max_leaf_nodes': 122, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 91}
# 0.7019142775973581 {'max_depth': 240, 'max_features': 1, 'max_leaf_nodes': 141, 'min_samples_leaf': 7, 'min_samples_split': 8, 'n_estimators': 351}
# 0.8902593173822704 {'max_depth': 197, 'max_features': 10, 'max_leaf_nodes': 416, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 307}
# 0.887106444388387 {'max_depth': 230, 'max_features': 11, 'max_leaf_nodes': 421, 'min_samples_leaf': 3, 'min_samples_split': 7, 'n_estimators': 153}
# 0.8851712773889346 {'max_depth': 112, 'max_features': 12, 'max_leaf_nodes': 479, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 106}
# 0.877739413538119 {'max_depth': 236, 'max_features': 18, 'max_leaf_nodes': 70, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 467}
# 0.8426856289396755 {'max_depth': 82, 'max_features': 3, 'max_leaf_nodes': 338, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 794}
# 0.8624197226483916 {'max_depth': 199, 'max_features': 15, 'max_leaf_nodes': 383, 'min_samples_leaf': 7, 'min_samples_split': 7, 'n_estimators': 443}
# 0.7189712420482913 {'max_depth': 52, 'max_features': 1, 'max_leaf_nodes': 238, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 464}
# 0.8758857883422652 {'max_depth': 130, 'max_features': 17, 'max_leaf_nodes': 400, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 77}
# 0.8560603729938568 {'max_depth': 188, 'max_features': 8, 'max_leaf_nodes': 490, 'min_samples_leaf': 7, 'min_samples_split': 8, 'n_estimators': 619}
# 0.8881476141116854 {'max_depth': 99, 'max_features': 9, 'max_leaf_nodes': 382, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 201}
# 0.8889265851211123 {'max_depth': 218, 'max_features': 10, 'max_leaf_nodes': 340, 'min_samples_leaf': 2, 'min_samples_split': 9, 'n_estimators': 864}
# 0.7250127970935282 {'max_depth': 83, 'max_features': 1, 'max_leaf_nodes': 127, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 328}
# 0.881457082887225 {'max_depth': 193, 'max_features': 17, 'max_leaf_nodes': 124, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 469}
# 0.7916348951761417 {'max_depth': 201, 'max_features': 3, 'max_leaf_nodes': 423, 'min_samples_leaf': 9, 'min_samples_split': 5, 'n_estimators': 445}
# 0.8727542029302642 {'max_depth': 79, 'max_features': 19, 'max_leaf_nodes': 51, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 84}
# 0.8854836719582725 {'max_depth': 71, 'max_features': 6, 'max_leaf_nodes': 321, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 144}
# 0.8866421356031353 {'max_depth': 49, 'max_features': 12, 'max_leaf_nodes': 259, 'min_samples_leaf': 1, 'min_samples_split': 9, 'n_estimators': 478}
# 0.8896239628983615 {'max_depth': 37, 'max_features': 10, 'max_leaf_nodes': 320, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 761}
# 0.8639176735186942 {'max_depth': 103, 'max_features': 20, 'max_leaf_nodes': 288, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 554}
# 0.8901604694211194 {'max_depth': 39, 'max_features': 7, 'max_leaf_nodes': 386, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 869}
# 0.8822928996186687 {'max_depth': 145, 'max_features': 19, 'max_leaf_nodes': 193, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 759}
# 0.8796857428821225 {'max_depth': 166, 'max_features': 11, 'max_leaf_nodes': 177, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 487}
# 0.8785148791302124 {'max_depth': 134, 'max_features': 9, 'max_leaf_nodes': 267, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 288}
# 0.6739177468329045 {'max_depth': 58, 'max_features': 1, 'max_leaf_nodes': 127, 'min_samples_leaf': 9, 'min_samples_split': 6, 'n_estimators': 957}
# 0.8732176250344768 {'max_depth': 159, 'max_features': 5, 'max_leaf_nodes': 472, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 866}
# 0.8830216884412103 {'max_depth': 202, 'max_features': 11, 'max_leaf_nodes': 486, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 230}
# 0.8281282039707758 {'max_depth': 208, 'max_features': 3, 'max_leaf_nodes': 499, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 378}
# 0.8316995999077962 {'max_depth': 166, 'max_features': 5, 'max_leaf_nodes': 152, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 62}
# 0.8683179558196168 {'max_depth': 74, 'max_features': 19, 'max_leaf_nodes': 344, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 645}
# 0.8684845827378005 {'max_depth': 129, 'max_features': 17, 'max_leaf_nodes': 460, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 407}
# 0.8259610088424892 {'max_depth': 225, 'max_features': 6, 'max_leaf_nodes': 94, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 882}
# 0.8096722374485278 {'max_depth': 33, 'max_features': 3, 'max_leaf_nodes': 157, 'min_samples_leaf': 6, 'min_samples_split': 8, 'n_estimators': 517}
# 0.8699578445858887 {'max_depth': 101, 'max_features': 16, 'max_leaf_nodes': 26, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 208}
# 0.8773811523256274 {'max_depth': 246, 'max_features': 20, 'max_leaf_nodes': 368, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 899}
# 0.8482229659351468 {'max_depth': 130, 'max_features': 9, 'max_leaf_nodes': 447, 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 723}
# 0.7061712246548335 {'max_depth': 176, 'max_features': 1, 'max_leaf_nodes': 490, 'min_samples_leaf': 6, 'min_samples_split': 9, 'n_estimators': 159}
# 0.8830938629856299 {'max_depth': 33, 'max_features': 15, 'max_leaf_nodes': 280, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 973}
# 0.8673487239658083 {'max_depth': 132, 'max_features': 11, 'max_leaf_nodes': 288, 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 648}
# 0.8677784926101954 {'max_depth': 129, 'max_features': 5, 'max_leaf_nodes': 143, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 252}
# 0.8819191741475041 {'max_depth': 117, 'max_features': 16, 'max_leaf_nodes': 290, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 199}
# 0.8751291881101094 {'max_depth': 226, 'max_features': 14, 'max_leaf_nodes': 333, 'min_samples_leaf': 5, 'min_samples_split': 9, 'n_estimators': 854}
# 0.8898358878410081 {'max_depth': 26, 'max_features': 12, 'max_leaf_nodes': 370, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 409}
# 0.8725197784185111 {'max_depth': 236, 'max_features': 11, 'max_leaf_nodes': 433, 'min_samples_leaf': 6, 'min_samples_split': 4, 'n_estimators': 161}
# 0.8714660140924501 {'max_depth': 185, 'max_features': 8, 'max_leaf_nodes': 413, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 555}
# 0.8779725187815821 {'max_depth': 217, 'max_features': 18, 'max_leaf_nodes': 375, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 143}
# 0.7958812977185099 {'max_depth': 10, 'max_features': 3, 'max_leaf_nodes': 369, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 507}
# 0.8350403028452776 {'max_depth': 154, 'max_features': 7, 'max_leaf_nodes': 335, 'min_samples_leaf': 9, 'min_samples_split': 7, 'n_estimators': 244}
# 0.8782980669117888 {'max_depth': 213, 'max_features': 18, 'max_leaf_nodes': 265, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 723}
# 0.8386340431690403 {'max_depth': 172, 'max_features': 19, 'max_leaf_nodes': 11, 'min_samples_leaf': 8, 'min_samples_split': 9, 'n_estimators': 378}
# 0.8466579839884953 {'max_depth': 165, 'max_features': 9, 'max_leaf_nodes': 400, 'min_samples_leaf': 8, 'min_samples_split': 9, 'n_estimators': 630}
# 0.8728536884991991 {'max_depth': 43, 'max_features': 20, 'max_leaf_nodes': 229, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 285}
# 0.8774291228197615 {'max_depth': 244, 'max_features': 17, 'max_leaf_nodes': 490, 'min_samples_leaf': 3, 'min_samples_split': 9, 'n_estimators': 30}
# 0.8631883277223619 {'max_depth': 248, 'max_features': 10, 'max_leaf_nodes': 16, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 872}
# 0.8078261405632278 {'max_depth': 143, 'max_features': 3, 'max_leaf_nodes': 347, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 821}
# 0.8319631389433262 {'max_depth': 4, 'max_features': 21, 'max_leaf_nodes': 77, 'min_samples_leaf': 7, 'min_samples_split': 7, 'n_estimators': 857}
# 0.8682197223748039 {'max_depth': 179, 'max_features': 12, 'max_leaf_nodes': 284, 'min_samples_leaf': 7, 'min_samples_split': 7, 'n_estimators': 671}
# 0.8453944826642525 {'max_depth': 24, 'max_features': 6, 'max_leaf_nodes': 276, 'min_samples_leaf': 7, 'min_samples_split': 3, 'n_estimators': 520}
# 0.8637238930312859 {'max_depth': 109, 'max_features': 16, 'max_leaf_nodes': 122, 'min_samples_leaf': 9, 'min_samples_split': 8, 'n_estimators': 725}
# 0.8826427305562822 {'max_depth': 127, 'max_features': 13, 'max_leaf_nodes': 259, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 434}
# 0.8649370972424407 {'max_depth': 203, 'max_features': 16, 'max_leaf_nodes': 236, 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 120}
# 0.8361431939514338 {'max_depth': 47, 'max_features': 7, 'max_leaf_nodes': 408, 'min_samples_leaf': 9, 'min_samples_split': 8, 'n_estimators': 411}
# 0.8317502630370702 {'max_depth': 87, 'max_features': 7, 'max_leaf_nodes': 360, 'min_samples_leaf': 9, 'min_samples_split': 7, 'n_estimators': 319}
# 0.8713146517662202 {'max_depth': 74, 'max_features': 5, 'max_leaf_nodes': 140, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 818}
# 0.8193620909320831 {'max_depth': 37, 'max_features': 2, 'max_leaf_nodes': 380, 'min_samples_leaf': 2, 'min_samples_split': 9, 'n_estimators': 745}
# 0.8708346808922215 {'max_depth': 180, 'max_features': 14, 'max_leaf_nodes': 326, 'min_samples_leaf': 6, 'min_samples_split': 6, 'n_estimators': 723}
# 0.8639176735186942 {'max_depth': 177, 'max_features': 20, 'max_leaf_nodes': 471, 'min_samples_leaf': 8, 'min_samples_split': 9, 'n_estimators': 584}
# 0.8621810221713403 {'max_depth': 162, 'max_features': 15, 'max_leaf_nodes': 100, 'min_samples_leaf': 9, 'min_samples_split': 4, 'n_estimators': 783}
# 0.8497160990705666 {'max_depth': 62, 'max_features': 6, 'max_leaf_nodes': 36, 'min_samples_leaf': 6, 'min_samples_split': 9, 'n_estimators': 622}
# 0.8191944054056345 {'max_depth': 35, 'max_features': 3, 'max_leaf_nodes': 160, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 994}
# 0.8920626407644751 {'max_depth': 171, 'max_features': 9, 'max_leaf_nodes': 119, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 971}
# 0.8628348674167894 {'max_depth': 165, 'max_features': 16, 'max_leaf_nodes': 181, 'min_samples_leaf': 9, 'min_samples_split': 7, 'n_estimators': 889}
# 0.6776474895607688 {'max_depth': 197, 'max_features': 1, 'max_leaf_nodes': 353, 'min_samples_leaf': 9, 'min_samples_split': 7, 'n_estimators': 697}
# 0.8491656969510384 {'max_depth': 49, 'max_features': 7, 'max_leaf_nodes': 354, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 744}
# 0.8754607922962053 {'max_depth': 119, 'max_features': 13, 'max_leaf_nodes': 64, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 984}
# 0.8736903066404128 {'max_depth': 176, 'max_features': 18, 'max_leaf_nodes': 158, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 101}
# 0.7958704604672959 {'max_depth': 83, 'max_features': 2, 'max_leaf_nodes': 74, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 193}
# 0.815035816750304 {'max_depth': 147, 'max_features': 2, 'max_leaf_nodes': 233, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 208}
# 0.8871439292306738 {'max_depth': 248, 'max_features': 6, 'max_leaf_nodes': 124, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 782}
# 0.8636318004734825 {'max_depth': 193, 'max_features': 14, 'max_leaf_nodes': 145, 'min_samples_leaf': 9, 'min_samples_split': 3, 'n_estimators': 309}
# 0.8803955163331179 {'max_depth': 21, 'max_features': 21, 'max_leaf_nodes': 373, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 579}
# 0.8858731754103559 {'max_depth': 11, 'max_features': 11, 'max_leaf_nodes': 406, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 677}
# 0.8779613261623389 {'max_depth': 68, 'max_features': 10, 'max_leaf_nodes': 344, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 295}
# 0.8436382010033141 {'max_depth': 55, 'max_features': 7, 'max_leaf_nodes': 169, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 81}
# 0.7982594137914637 {'max_depth': 112, 'max_features': 3, 'max_leaf_nodes': 50, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 857}
# 0.8621796530696694 {'max_depth': 102, 'max_features': 15, 'max_leaf_nodes': 104, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 162}
# 0.8629165485382135 {'max_depth': 249, 'max_features': 5, 'max_leaf_nodes': 121, 'min_samples_leaf': 3, 'min_samples_split': 9, 'n_estimators': 54}
# 0.8688457662824132 {'max_depth': 7, 'max_features': 21, 'max_leaf_nodes': 124, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 516}
# 0.8433887542886478 {'max_depth': 104, 'max_features': 3, 'max_leaf_nodes': 178, 'min_samples_leaf': 3, 'min_samples_split': 7, 'n_estimators': 359}
# 0.8150945534474128 {'max_depth': 173, 'max_features': 1, 'max_leaf_nodes': 411, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 199}
# 0.8900566362485206 {'max_depth': 81, 'max_features': 10, 'max_leaf_nodes': 471, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 249}
# 0.8654610398463228 {'max_depth': 28, 'max_features': 20, 'max_leaf_nodes': 253, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 568}
# 0.8805326181276178 {'max_depth': 84, 'max_features': 17, 'max_leaf_nodes': 341, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 672}
# Best:  {'max_depth': 171, 'max_features': 9, 'max_leaf_nodes': 119, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 971}

# %%
from sklearn.model_selection import GridSearchCV
forest_clf = RandomForestClassifier(random_state=32)

param_grid = {'n_estimators': range(200, 350, 25),
              'min_samples_split': range(3,12,3),
              'max_depth': range(80,120,20),
              'min_samples_leaf': range(1,3),
              'max_features': range(6,16,2),
              'max_leaf_nodes': range(100,200,50)
              }

grid_search = GridSearchCV(forest_clf, param_grid, cv=5,
                           scoring = f2_score, return_train_score=True)

grid_search.fit(train_prepared, train_label)

cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
  if mean_score > 1.2:
    print(mean_score, params)

print("Best Parameters: ", grid_search.best_params_)
# Out:
# Best Parameters:  {'max_depth': 80, 'max_features': 10, 'max_leaf_nodes': 100, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 325}

# %%
#BEST MODEL
forest_clf = RandomForestClassifier(max_depth= 80, max_features= 8,
                                    max_leaf_nodes= 100, min_samples_leaf= 2,
                                    min_samples_split= 3, n_estimators= 325)

forest_clf.fit(train_prepared, train_label)

y_pred = forest_clf.predict(test_prepared)
print("Random Forest Accuracy: ", accuracy_score(test_label, y_pred))
best_scores = clf_scores(test_label, y_pred);

# %% [markdown]
# Compare to un-optimized:

# %%
#Pre-optimization results for comparison
y_pred = rnd_clf.predict(test_prepared)
print(rnd_clf.__class__.__name__, accuracy_score(test_label, y_pred))
pre_opt_scores = clf_scores(test_label, y_pred);

# %%
score_label = ["Confusion Matrix Difference", "Recall Difference", "Precision Difference", "F1 Score Difference"]
for i in range(len(best_scores)):
    print(score_label[i])
    print(best_scores[i]-pre_opt_scores[i])
